# %%
import pandas as pd
df = pd.read_csv('Day_8_sales_data.csv')
sales_greater_than_1000 = df[df['Sales'] > 1000]
print("Rows where Sales are greater than 1000:")
print(sales_greater_than_1000)
sales_for_east = df[df['Region'] == 'East']
print("\nSales records for the 'East' region:")
print(sales_for_east)
df['Profit_Per_Unit'] = df['Profit'] / df['Quantity']
print("\nData with the new column 'Profit_Per_Unit':")
print(df[['Region', 'Product', 'Sales', 'Quantity', 'Profit', 'Profit_Per_Unit']])
df['High_Sales'] = df['Sales'].apply(lambda x: 'Yes' if x > 1000 else 'No')
print("\nData with the new column 'High_Sales':")
print(df[['Region', 'Product', 'Sales', 'High_Sales']])
# Out:
# Rows where Sales are greater than 1000:
#           Date     Product Region    Sales  Profit  Quantity
# 0   2023-01-02      Tablet   East  1061.81  236.12         7
# 1   2023-01-06      Laptop  North  1926.07  246.34         8
# 2   2023-01-03      Tablet   East  1597.99  253.17         3
# 3   2023-01-20      Tablet  North  1397.99  242.23         1
# 7   2023-01-07  Smartphone   East  1799.26  364.97         4
# 8   2023-01-11  Smartphone   West  1401.67  306.24         2
# 9   2023-01-01      Laptop  North  1562.11  170.72         6
# 11  2023-01-12      Laptop   West  1954.86  262.16         4
# 12  2023-01-09     Monitor  North  1748.66  197.62         6
# 17  2023-01-18     Monitor   West  1287.13  153.86         7
# 18  2023-01-13      Tablet   West  1147.92  271.88         9
#
# Sales records for the 'East' region:
#           Date     Product Region    Sales  Profit  Quantity
# 0   2023-01-02      Tablet   East  1061.81  236.12         7
# 2   2023-01-03      Tablet   East  1597.99  253.17         3
# 6   2023-01-14    Keyboard   East   587.13   82.16         8
# 7   2023-01-07  Smartphone   East  1799.26  364.97         4
# 14  2023-01-08      Laptop   East   772.74  226.51         2
#
# Data with the new column 'Profit_Per_Unit':
#    Region     Product    Sales  Quantity  Profit  Profit_Per_Unit
# 0    East      Tablet  1061.81         7  236.12        33.731429
# 1   North      Laptop  1926.07         8  246.34        30.792500
# 2    East      Tablet  1597.99         3  253.17        84.390000
# 3   North      Tablet  1397.99         1  242.23       242.230000
# 4    West      Laptop   734.03         4  140.36        35.090000
# 5   North      Tablet   733.99         2  188.66        94.330000
# 6    East    Keyboard   587.13         8   82.16        10.270000
# 7    East  Smartphone  1799.26         4  364.97        91.242500
# 8    West  Smartphone  1401.67         2  306.24       153.120000
# 9   North      Laptop  1562.11         6  170.72        28.453333
# 10  North     Monitor   530.88         6  117.59        19.598333
# 11   West      Laptop  1954.86         4  262.16        65.540000
# 12  North     Monitor  1748.66         6  197.62        32.936667
# 13  North  Smartphone   818.51         2  237.19       118.595000
# 14   East      Laptop   772.74         2  226.51       113.255000
# 15  North    Keyboard   775.11         4  202.83        50.707500
# 16  North      Tablet   956.36         8  153.90        19.237500
# 17   West     Monitor  1287.13         7  153.86        21.980000
# 18   West      Tablet  1147.92         9  271.88        30.208889
# 19  South      Tablet   936.84         8  176.15        22.018750
#
# Data with the new column 'High_Sales':
#    Region     Product    Sales High_Sales
# 0    East      Tablet  1061.81        Yes
# 1   North      Laptop  1926.07        Yes
# 2    East      Tablet  1597.99        Yes
# 3   North      Tablet  1397.99        Yes
# 4    West      Laptop   734.03         No
# 5   North      Tablet   733.99         No
# 6    East    Keyboard   587.13         No
# 7    East  Smartphone  1799.26        Yes
# 8    West  Smartphone  1401.67        Yes
# 9   North      Laptop  1562.11        Yes
# 10  North     Monitor   530.88         No
# 11   West      Laptop  1954.86        Yes
# 12  North     Monitor  1748.66        Yes
# 13  North  Smartphone   818.51         No
# 14   East      Laptop   772.74         No
# 15  North    Keyboard   775.11         No
# 16  North      Tablet   956.36         No
# 17   West     Monitor  1287.13        Yes
# 18   West      Tablet  1147.92        Yes
# 19  South      Tablet   936.84         No
